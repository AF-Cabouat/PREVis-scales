# %%
import os
# from os.path import exists
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib as mpl
import seaborn as sns

import numpy as np

# %%
print('Seaborn version > 0.13 is required. Your version is:')
print(sns.__version__)
# Out:
# Seaborn version > 0.13 is required. Your version is:
# 0.13.2

# %% [markdown]
# ## Variables

# %%
#Declare our variables
data_dir = '../Data'
main_dir = '../Data_Analysis'
sub_dir = '' #if we have another structure

dir = main_dir+sub_dir
plots_outdir = f'{main_dir}/RatingPlots'

if not os.path.exists(plots_outdir):
    os.makedirs(plots_outdir)

# if not os.path.exists(f'{plots_outdir}-factors'):
#     os.makedirs(f'{plots_outdir}-factors')

#list of conditions (used in questions' codes)
conditions = [
    'A',
    'B',
    'C'
]

PREVis_scale = {
    "Understand" : ['obvious', 'represent', 'understandEasi'],
    "Layout" : ['messi', 'crowd', 'distract'],
    "DataFeat" : ['visibl', 'see'],
    "DataRead" : ['inform','identifi','find']
}

#items names

items = [
'crowd',
'distract',
'find',
'identifi',
'inform',
'messi',
'obvious',
'represent',
'see',
'understandEasi',
'visibl',
]

#color + desaturated color
colors = {
    "Understand" : ['#4ba1bc','#829599'],
    "Layout" : ['#839e49', '#969b86'],
    "DataRead" : ['#a87c9f', '#a396a0'],
    "DataFeat" : ['#e08095', '#c6b6ba']
}

# %% [markdown]
# # Load answers

# %%
df = pd.read_csv(f'{data_dir}/full_answers_by_stimuli.csv')
df = df[['stimulus']+items]
df
# Out:
#     stimulus  crowd  distract  find  identifi  inform  messi  obvious  \
# 0          A      5         6     6         5       6      5        3
# 1          A      7         7     7         7       7      7        7
# 2          A      7         7     7         7       7      7        7
# 3          A      6         5     5         3       3      5        5
# 4          A      6         5     6         6       7      6        7
# ..       ...    ...       ...   ...       ...     ...    ...      ...
# 439        C      1         2     4         3       1      1        6
# 440        C      2         2     2         2       3      2        4
# 441        C      5         6     4         4       4      4        6
# 442        C      1         1     2         2       2      1        4
# 443        C      1         1     1         1       1      1        2
#
#      represent  see  understandEasi  visibl
# 0            3    6               4       6
# 1            7    7               7       7
# 2            7    7               7       7
# 3            6    3               6       2
# 4            7    6               7       6
# ..         ...  ...             ...     ...
# 439          6    3               6       4
# 440          5    3               4       5
# 441          5    4               6       3
# 442          4    2               3       6
# 443          6    1               1       1
#
# [444 rows x 12 columns]

# %% [markdown]
# # Plots individual items

# %% [markdown]
# ## For each stimulus, plot individual items against full factor

# %%
# per stimulus, all factor items
def make_plots_per_stimulusXfactor_across_items(d, condition_list, factor_dict, fileprefix='', colors_dict='hls'):
    
    if 'PREVis' in fileprefix:
        legend_average_name = 'PREVis-subscale'
        folder = plots_outdir
    elif 'factors' in fileprefix:
        legend_average_name = 'factor'
        folder = f'{plots_outdir}-factors'
    
    for c in condition_list:
        this_c_df = d[d['stimulus'] == c]
        this_c_df.drop(columns=['stimulus'], inplace=True)

        for f in factor_dict:
            this_f_average_cat_name = f'{f}\n{legend_average_name} average'

            this_c_f_df = this_c_df[factor_dict[f]]
            this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)

            if isinstance(colors_dict, dict):
                sns.set_palette(colors_dict[f]) 
            elif isinstance(colors_dict, list):
                sns.set_palette(colors_dict)

            df_to_plot = pd.DataFrame()
            for col in this_c_f_df.columns:
                this_col_df = pd.DataFrame(this_c_f_df[col])
                this_col_df.rename(columns={col:'rating'}, inplace=True)
                this_col_df['cat'] = col
                df_to_plot = pd.concat([df_to_plot, this_col_df], axis=0, ignore_index=True)

            sns.set_palette(colors[f]) 

            fig2 = plt.figure(figsize=(5,1))

            ax2 = sns.pointplot(
                data=df_to_plot[df_to_plot['cat']==this_f_average_cat_name], x='rating', y="cat", 
                #hue='type', dodge=0.3,
                errorbar="ci", capsize=0,
                linestyle="none", linewidth=1.5,
                marker="D", markersize=4,
            )

            ax2.set_xlim(left=1, right=7)

            #first line object is the point
            point_line = ax2.lines[0]
            x, y = point_line.get_xydata().T
            rating_point = x

            CI_line = ax2.lines[1]
            ci_coord = CI_line.__dict__['_xorig']
            ci_width = ci_coord[1]-ci_coord[0]
            print("CI width=", ci_width)


            for line in ax2.lines:
                # Get the x and y coordinates of the line
                print(line)
                if isinstance(line, mpl.lines.Line2D) and '_xorig' in line.__dict__:
                    print('Found CI bar')
                    # Extract the error bar data
                    
                    rating_point = np.mean(x)  # Get the x value (rating point)
                    break

            plt.show(fig2)


            # get number of items to plot to calculate height of figure
            nb_items = len(df_to_plot['cat'].unique())
            # fig_height = nb_items/2+0.2
            # fig = plt.figure(figsize=(8,fig_height))
            fig = plt.figure()

            ax1 = sns.pointplot(
                data=df_to_plot[df_to_plot['cat']!=this_f_average_cat_name], x='rating', y="cat", 
                errorbar="ci", capsize=0,
                linestyle="none", linewidth=1.5,
                marker="D", markersize=4,
            )
            

            #background grey color
            ax1.set_facecolor((0.9,0.9,0.9))
            

            #plot average and CI rectangle
            ax1.axvline(x=rating_point, color=colors[f][1], alpha = 0.8, zorder=2)
            # Calculate the left and right boundaries of the rectangle
            left = rating_point - ci_width / 2
            right = rating_point + ci_width / 2
            

            # Plot the rectangle
            ax1.add_patch(plt.Rectangle((left, -0.5), ci_width, len(df_to_plot['cat'].unique()), color=colors[f][1], alpha=0.2, zorder=2))

            # x axis parameters
            ax1.set_xlim(left=1, right=7)
            ax1.set_xlabel(f'Stimulus {c}: mean ratings and 95% CI')

            # Manually plot vertical lines following x-axis ticks
            for x_tick in ax1.get_xticks()[0:]: #ignoring the first tick
                ax1.axvline(x_tick, color=((0,0,0,0.1)), linewidth=1, zorder=5)

            # y axis parameters
            ax1.tick_params(axis='y', width=0) # remove ticks
            # ax1.grid(axis='y', linewidth=12+fig_height, color='white', alpha=0.95, zorder=0)
            ax1.grid(axis='y', linewidth=18, color='white', alpha=0.95, zorder=0)
            ax1.set_ylabel('')
            
            
            sns.despine(left=True, top=True, right=True) #removing the frame
            

            def set_size(w,h, ax=None): #https://stackoverflow.com/questions/44970010/axes-class-set-explicitly-size-width-height-of-axes-in-given-units
                """ w, h: width, height in inches """
                if not ax: ax=plt.gca()
                l = ax.figure.subplotpars.left
                r = ax.figure.subplotpars.right
                t = ax.figure.subplotpars.top
                b = ax.figure.subplotpars.bottom
                figw = float(w)/(r-l)
                figh = float(h)/(t-b)
                ax.figure.set_size_inches(figw, figh)

            set_size(5,nb_items/5)

            plt.show(fig)

            # plt.show(g)
            fig.savefig(f"{folder}/{c}-{fileprefix}_{f}.pdf", bbox_inches='tight')



make_plots_per_stimulusXfactor_across_items(df, conditions, PREVis_scale, fileprefix='PREVis_items_ratings', colors_dict=colors)
# Out:
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_df.drop(columns=['stimulus'], inplace=True)
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# CI width= 0.2680743243243242
# Line2D(_child0)
# Found CI bar
# CI width= 0.38969594594594614
# Line2D(_child0)
# Found CI bar
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# CI width= 0.3345439189189179
# Line2D(_child0)
# Found CI bar
# CI width= 0.26137387387387534
# Line2D(_child0)
# Found CI bar
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# CI width= 0.46407657657657797
# Line2D(_child0)
# Found CI bar
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_df.drop(columns=['stimulus'], inplace=True)
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# CI width= 0.45962837837837833
# Line2D(_child0)
# Found CI bar
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# CI width= 0.46959459459459385
# Line2D(_child0)
# Found CI bar
# CI width= 0.4617117117117111
# Line2D(_child0)
# Found CI bar
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# CI width= 0.5382882882882871
# Line2D(_child0)
# Found CI bar
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_df.drop(columns=['stimulus'], inplace=True)
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# CI width= 0.36036036036036023
# Line2D(_child0)
# Found CI bar
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)
# CI width= 0.483277027027027
# Line2D(_child0)
# Found CI bar
# CI width= 0.5023648648648651
# Line2D(_child0)
# Found CI bar
# /var/folders/ll/myjb0w6s7q95cmn7vm6lpghc0000gn/T/ipykernel_4050/916980655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_c_f_df[this_f_average_cat_name] = this_c_f_df.mean(axis=1)

# %% [markdown]
# # Plot averages only

# %%
#plot each item across multiple stimuli

def make_plots_per_scale_across_stimuli(d, factor_dict, fileprefix, together = True):
    folder = plots_outdir

    scales_colors = []

    df_to_plot = pd.DataFrame()

    for f in factor_dict:
        this_f_cols = factor_dict[f]
        this_f_d = pd.DataFrame(df[this_f_cols].mean(axis=1), columns=['ratings'])
        this_f_d['subscale'] = f
        this_f_d['stimulus'] = d['stimulus']

        df_to_plot = pd.concat([df_to_plot, this_f_d], axis=0, ignore_index=True)

        scales_colors += [colors[f][0]]

        
    sns.set_palette(scales_colors)  

    if together:   
        fig = plt.figure(figsize=(8,2))

        ax1 = sns.pointplot(
            data=df_to_plot,
            x='ratings',
            y="stimulus",
            hue='subscale', dodge=0.7,
            errorbar="ci", capsize=0,
            linestyle="none", linewidth=1.5,
            marker="D", markersize=4,
        )
        
        #background grey color
        ax1.set_facecolor((0.9,0.9,0.9))

        # x axis parameters
        ax1.set_xlim(left=1, right=7)
        ax1.set_xlabel('Subscales mean ratings and 95% CI')

        # Manually plot vertical lines following x-axis ticks
        for x_tick in ax1.get_xticks()[0:]: #ignoring the first tick
            ax1.axvline(x_tick, color=((0,0,0,0.1)), linewidth=1, zorder=5)

        # y axis parameters
        ax1.tick_params(axis='y', width=0) # remove ticks
        ax1.grid(axis='y', linewidth=36, color='white', alpha=0.95, zorder=0)
        ax1.set_ylabel('Stimuli in survey')
        
        ax1.legend(title='', loc='upper left', edgecolor='white')

        # sns.move_legend(ax1, "lower right", bbox_to_anchor=(1, 1))
        sns.despine(left=True, top=True, right=True) #removing the frame

        plt.show(fig)
        fig.savefig(f"{folder}/{fileprefix}.pdf", bbox_inches='tight')
    
    if not together:
        print(scales_colors)
        for subscale in factor_dict.keys():

            print(subscale)

            # Filter data for the current subscale
            subscale_data = df_to_plot[df_to_plot['subscale'] == subscale]
            
            fig, ax = plt.subplots(figsize=(8, 2))
            sns.pointplot(
                data=subscale_data,
                x='ratings',
                y="stimulus",
                color=colors[subscale][0],
                errorbar="ci", capsize=0,
                linestyle="none", linewidth=1.5,
                marker="D", markersize=4,
                ax=ax
            )

            ax.set_facecolor((0.9, 0.9, 0.9))
            ax.set_xlim(left=0.9, right=7.1)  # Adjusted for margin
            ax.set_xlabel(f'{subscale} mean ratings and 95% CI')
            for x_tick in ax.get_xticks():
                ax.axvline(x_tick, color=((0, 0, 0, 0.1)), linewidth=1, zorder=5)
            ax.tick_params(axis='y', width=0)
            ax.grid(axis='y', linewidth=36, color='white', alpha=0.95, zorder=0)
            ax.set_ylabel('Stimuli in survey')
            ax.legend(title='', loc='upper left', edgecolor='white')
            sns.despine(left=True, top=True, right=True)
            plt.show()
            fig.savefig(f"{folder}/{fileprefix}_{subscale}.pdf", bbox_inches='tight')

# Example usage

make_plots_per_scale_across_stimuli(df, PREVis_scale, 'PREVis_subscales_ratings', together=False)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ['#4ba1bc', '#839e49', '#e08095', '#a87c9f']
# Understand
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Layout
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# DataFeat
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# DataRead

# %%
#plot all scale averages across multiple stimuli (one plot)

def make_plots_per_scale_across_stimuli(d, factor_dict, fileprefix):
    folder = plots_outdir

    scales_colors = []

    df_to_plot = pd.DataFrame()

    for f in factor_dict:
        this_f_cols = factor_dict[f]
        this_f_d = pd.DataFrame(df[this_f_cols].mean(axis=1), columns=['ratings'])
        this_f_d['subscale'] = f
        this_f_d['stimulus'] = d['stimulus']

        df_to_plot = pd.concat([df_to_plot, this_f_d], axis=0, ignore_index=True)

        scales_colors += [colors[f][0]]

        
    sns.set_palette(scales_colors)     
    fig = plt.figure(figsize=(8,2))

    # sns.pointplot(
    #     ax = ax1,
    ax1 = sns.pointplot(
        data=df_to_plot,
        x='ratings',
        y="stimulus",
        hue='subscale', dodge=0.7,
        errorbar="ci", capsize=0,
        linestyle="none", linewidth=1.5,
        marker="D", markersize=4,
    )
    
    #background grey color
    ax1.set_facecolor((0.9,0.9,0.9))

    # x axis parameters
    ax1.set_xlim(left=1, right=7)
    ax1.set_xlabel('Subscales mean ratings and 95% CI')

    # Manually plot vertical lines following x-axis ticks
    for x_tick in ax1.get_xticks()[0:]: #ignoring the first tick
        ax1.axvline(x_tick, color=((0,0,0,0.1)), linewidth=1, zorder=5)

    # y axis parameters
    ax1.tick_params(axis='y', width=0) # remove ticks
    ax1.grid(axis='y', linewidth=36, color='white', alpha=0.95, zorder=0)
    ax1.set_ylabel('Stimuli in survey')
    
    ax1.legend(title='', loc='upper left', edgecolor='white')

    # sns.move_legend(ax1, "lower right", bbox_to_anchor=(1, 1))
    sns.despine(left=True, top=True, right=True) #removing the frame

    plt.show(fig)
    fig.savefig(f"{folder}/{fileprefix}.pdf", bbox_inches='tight')

# %%
# This line will generate the Fig. 5 (bottom part) in the PREVis paper
# It will go to the RatingPlots folder
make_plots_per_scale_across_stimuli(df, PREVis_scale, 'PREVis_subscales_ratings')

# %% [markdown]
# # An example of what NOT to do: aggregation of subscales as one score

# %%
'''

means_df = pd.DataFrame(df['stimulus'])

for scale in PREVis_scale.keys():
    d_scale = df[PREVis_scale[scale]]
    print(d_scale)
    means_df.insert(1, scale, d_scale.mean(axis=1))
    
d = pd.DataFrame(df['stimulus'])
d.insert(1, 'PREVis average', means_df[[col for col in means_df if col !='stimulus']].mean(axis=1))

fig = plt.figure(figsize=(8,2))

# sns.pointplot(
#     ax = ax1,
ax1 = sns.pointplot(
    data=d,
    x='PREVis average',
    y="stimulus",
    color='black',
    # dodge=0.7,
    errorbar="ci", capsize=0,
    linestyle="none", linewidth=1.5,
    marker="D", markersize=4,
)

#background grey color
ax1.set_facecolor((0.9,0.9,0.9))

# x axis parameters
ax1.set_xlim(left=1, right=7)
ax1.set_xlabel('Subscales mean ratings and 95% CI')

# Manually plot vertical lines following x-axis ticks
for x_tick in ax1.get_xticks()[0:]: #ignoring the first tick
    ax1.axvline(x_tick, color=((0,0,0,0.1)), linewidth=1, zorder=5)

# y axis parameters
ax1.tick_params(axis='y', width=0) # remove ticks
ax1.grid(axis='y', linewidth=36, color='white', alpha=0.95, zorder=0)
ax1.set_ylabel('Stimuli in survey')

# ax1.legend(title='', loc='upper left', edgecolor='white')

# sns.move_legend(ax1, "lower right", bbox_to_anchor=(1, 1))
sns.despine(left=True, top=True, right=True) #removing the frame

plt.show(fig)
# fig.savefig(f"{folder}/{fileprefix}.pdf", bbox_inches='tight')

'''
# Out:
# '\n\nmeans_df = pd.DataFrame(df[\'stimulus\'])\n\nfor scale in PREVis_scale.keys():\n    d_scale = df[PREVis_scale[scale]]\n    print(d_scale)\n    means_df.insert(1, scale, d_scale.mean(axis=1))\n    \nd = pd.DataFrame(df[\'stimulus\'])\nd.insert(1, \'PREVis average\', means_df[[col for col in means_df if col !=\'stimulus\']].mean(axis=1))\n\nfig = plt.figure(figsize=(8,2))\n\n# sns.pointplot(\n#     ax = ax1,\nax1 = sns.pointplot(\n    data=d,\n    x=\'PREVis average\',\n    y="stimulus",\n    color=\'black\',\n    # dodge=0.7,\n    errorbar="ci", capsize=0,\n    linestyle="none", linewidth=1.5,\n    marker="D", markersize=4,\n)\n\n#background grey color\nax1.set_facecolor((0.9,0.9,0.9))\n\n# x axis parameters\nax1.set_xlim(left=1, right=7)\nax1.set_xlabel(\'Subscales mean ratings and 95% CI\')\n\n# Manually plot vertical lines following x-axis ticks\nfor x_tick in ax1.get_xticks()[0:]: #ignoring the first tick\n    ax1.axvline(x_tick, color=((0,0,0,0.1)), linewidth=1, zorder=5)\n\n# y axis parameters\nax1.tick_params(axis=\'y\', width=0) # remove ticks\nax1.grid(axis=\'y\', linewidth=36, color=\'white\', alpha=0.95, zorder=0)\nax1.set_ylabel(\'Stimuli in survey\')\n\n# ax1.legend(title=\'\', loc=\'upper left\', edgecolor=\'white\')\n\n# sns.move_legend(ax1, "lower right", bbox_to_anchor=(1, 1))\nsns.despine(left=True, top=True, right=True) #removing the frame\n\nplt.show(fig)\n# fig.savefig(f"{folder}/{fileprefix}.pdf", bbox_inches=\'tight\')\n\n'
